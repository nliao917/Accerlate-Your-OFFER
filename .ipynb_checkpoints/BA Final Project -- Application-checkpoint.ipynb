# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import csv
import pandas as pd
import numpy as np
# do the LDA
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.parsing.preprocessing import STOPWORDS
import pprint
import nltk
from nltk import sent_tokenize,word_tokenize
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
with open('Feature_List', newline='') as f:
    reader = csv.reader(f)
    feature_list = list(reader)

# %%
BA_feature=feature_list[0]
DA_feature=feature_list[1]
DS_feature=feature_list[2]
DE_feature=feature_list[3]

# %%
all_feature=BA_feature+DA_feature+DS_feature+DE_feature

# %%
len(all_feature)
# Out:
# 40

# %%
len(set(all_feature))
# Out:
# 27

# %%
clean=["we","our","us","itself","employees","firm","apply","disabilities",
       "re","company","description","accomendation","\nWe","relocation","location"]
stop_words = set(stopwords.words('english')) 
def clean_JD(jd,name):
    name=[x.lower() for x in word_tokenize(name) if x.isalnum()]
    if len(name)>1:
        s=""
        try:
            for i in name:
                s+=i[0]
            name+=[s]
        except:
            pass
    res=""
    for sentence in sent_tokenize(jd):
        for j in sentence.split("\n"):
            if not j: continue
            sent=[]
            for x in word_tokenize(j):
                if x.isalnum():
                    sent.append(x.lower())
            A=set(sent)
            B=set(name+clean)
            if not A&B:
                res+=j+"\n"
    word_tokens = word_tokenize(res)
    wordlist=[word for word in word_tokens if word.isalnum() and word not in stop_words]
    full_text=""
    for word in wordlist:
        full_text+=word+" "
    
    return full_text

# %%
from nltk import pos_tag
from nltk.stem import PorterStemmer

ps = PorterStemmer()

# process the keywords
ba_feature_set = set([ps.stem(tok) for tok in BA_feature]) 
da_feature_set = set([ps.stem(tok) for tok in DA_feature]) 
ds_feature_set = set([ps.stem(tok) for tok in DS_feature]) 
de_feature_set = set([ps.stem(tok) for tok in DE_feature])
all_feature_set = set([ps.stem(tok) for tok in all_feature])

# %%
de_feature_set
# Out:
# {'aw',
#  'big',
#  'cloud',
#  'engin',
#  'etl',
#  'infrastructur',
#  'pipelin',
#  'python',
#  'spark',
#  'statist'}

# %%
# process the job description.
def prepare_job_desc(desc):
    # tokenize description.
    desc=desc.replace("-"," ")
    desc=desc.replace("/"," ")
    tokens = [x for x in word_tokenize(desc) if x.isalnum()]
    # Parts of speech (POS) tag tokens.
    token_tag = pos_tag(tokens)
    
    # Only include some of the POS tags.
    include_tags = ['VBN', 'VBD', 'JJ', 'JJS', 'JJR', 'CD', 'NN', 'NNS', 'NNP', 'NNPS']
    filtered_tokens = [tok for tok, tag in token_tag if tag in include_tags]
    
    # stem words.
    stemmed_tokens = [ps.stem(tok).lower() for tok in filtered_tokens]
    return set(stemmed_tokens)

# %%
def mapping_list(df):
    #name=get_df_name(df)
    #df['details']=name.split("_")[1]
    df['job_description_word_set'] =df['newdetails'].map(prepare_job_desc)
    
    ba_feature = []
    da_feature = []
    ds_feature = []
    de_feature = []
    all_feature = []
   

    num_postings = len(df.index)
    for i in range(num_postings):
        #job_desc = df.iloc[i]['newdetails'].lower()
        job_desc_set = df.iloc[i]['job_description_word_set']

        # check if the keywords are in the job description. Look for exact match by token.
        ba = ba_feature_set.intersection(job_desc_set)
        da = da_feature_set.intersection(job_desc_set)
        ds = ds_feature_set.intersection(job_desc_set)
        de = de_feature_set.intersection(job_desc_set)
        al = all_feature_set.intersection(job_desc_set)

        
        if len(ba) == 0:
            ba=[None]
        if len(da) == 0:
            da=[None]
        if len(ds) == 0:
            ds=[None]
        if len(de) == 0:
            de=[None]
        if len(al) == 0:
            al=[None]
    
                
        ba_feature.append(list(ba))
        da_feature.append(list(da))
        ds_feature.append(list(ds))
        de_feature.append(list(de))
        all_feature.append(list(al))
    
    return ba_feature, da_feature, ds_feature, de_feature,all_feature

# %%
def df_with_feature(df):
    ba, da, ds, de, al= mapping_list(df)
    df["ba"]=ba
    df["da"]=da
    df["ds"]=ds
    df["de"]=de
    df["all"]=al
   
    return df

# %%
def all(file_name):
    df=pd.read_csv(file_name)[0:5]
    df['newdetails'] =df.apply(lambda x: clean_JD(x['details'],x['company']),axis=1)
    df_with_feature(df)
    return df

# %%
all("BA_JD.csv")
# Out:
#    Unnamed: 0                                           position  \
# 0           0                            Business Analyst Intern
# 1           1                            Business Analyst Intern
# 2           2                                   Business Analyst
# 3           3  U.S. Private Banking & Wealth Business Analyti...
# 4           4                            Business Analyst Intern
#
#                company                   location  \
# 0  RM Talent Solutions  Washington, United States
# 1  RM Talent Solutions       Maine, United States
# 2                Cisco               New York, NY
# 3                 Citi               New York, NY
# 4        2 a.m. Talent           Jacksonville, FL
#
#                                              details  \
# 0  Posted by\nAzhar Ali Khan\nTalent Acquisition ...
# 1  Posted by\nKhalid Ansari\nRecruitment Speciali...
# 2  Who We Are\n\nCisco Security – at Cisco we del...
# 3  Job Id: 22461117\n\nThis is a Business Analyti...
# 4  Responsibilities vary depending on assigned pr...
#
#                                           newdetails  \
# 0  Posted Azhar Ali Khan Send InMail Business Ana...
# 1  Posted Khalid Ansari Send InMail Eligibility C...
# 2  Who You Are As Security Licensing Specialist a...
# 3  Job Id 22461117 The analyst work closely Finan...
# 4  Responsibilities vary depending assigned proje...
#
#                             job_description_word_set  \
# 0  {applic, employ, job, internship, techniqu, fo...
# 1  {job, applic, employ, khalid, toward, desir, i...
# 2  {applic, track, servic, detail, opportun, cons...
# 3  {applic, loss, view, foundat, deep, capabl, de...
# 4  {applic, familiar, experi, internship, servic,...
#
#                                               ba                    da  \
# 0                                       [commun]                [None]
# 1                                         [None]                [None]
# 2                                       [commun]        [engin, excel]
# 3  [python, commun, statist, learn, sql, analyt]  [excel, sql, analyt]
# 4                                       [commun]               [excel]
#
#                          ds                 de  \
# 0                    [None]             [None]
# 1                    [None]             [None]
# 2                    [None]     [engin, cloud]
# 3  [statist, python, learn]  [statist, python]
# 4                    [None]    [infrastructur]
#
#                                                  all
# 0                                           [commun]
# 1                                             [None]
# 2                      [engin, excel, cloud, commun]
# 3  [python, excel, commun, statist, learn, sql, a...
# 4                     [excel, infrastructur, commun]

# %%
all("DA_JD.csv")
# Out:
#    Unnamed: 0                                           position      company  \
# 0           0                                       Data Analyst  Robert Half
# 1           1  Data Analyst - Target Circle (Full-Time Remote...       Target
# 2           2                                       Data Analyst         Dice
# 3           3                                       Data Analyst    DistroKid
# 4           4                         LATAM Markets Data Analyst         Citi
#
#           location                                            details  \
# 0     New York, NY  Description\nPerforming UAT testing of new or ...
# 1  Minneapolis, MN  Description\n\nAbout us:\n\nTarget is an iconi...
# 2     New York, NY  Dice is the leading career destination for tec...
# 3    United States  Summary\n\nThe DistroKid Product team is looki...
# 4     New York, NY  Job Id: 22460268\n\nThis AVP Data Analyst role...
#
#                                           newdetails  \
# 0  Performing UAT testing new changed processes r...
# 1  Behind one world best loved brands uniquely ca...
# 2  OracleSQL PLSQL Python R Tableau With BSA AML ...
# 3  Summary The ideal candidate highly motivated r...
# 4  Job Id 22460268 This AVP Data Analyst role sup...
#
#                             job_description_word_set  \
# 0  {applic, job, experi, equal, employ, technolog...
# 1  {love, toward, capabl, abl, creation, execut, ...
# 2  {experi, servic, oraclesql, financi, backgroun...
# 3  {servic, extra, detail, signific, data, degre,...
# 4  {applic, view, latam, 21, repositori, adopt, d...
#
#                                                   ba  \
# 0                                              [sql]
# 1  [python, scientist, commun, statist, learn, sq...
# 2                                           [python]
# 3             [python, commun, statist, sql, analyt]
# 4                  [statist, machin, commun, analyt]
#
#                                               da  \
# 0                                   [excel, sql]
# 1  [excel, engin, scientist, spark, sql, analyt]
# 2                                         [None]
# 3                                  [sql, analyt]
# 4                        [engin, machin, analyt]
#
#                                              ds  \
# 0                                        [None]
# 1  [python, scientist, quantit, statist, learn]
# 2                                      [python]
# 3                    [regress, python, statist]
# 4  [regress, machin, statist, quantit, predict]
#
#                                 de  \
# 0                           [None]
# 1  [engin, spark, python, statist]
# 2                         [python]
# 3                [statist, python]
# 4        [engin, statist, pipelin]
#
#                                                  all
# 0                                       [excel, sql]
# 1  [python, excel, engin, scientist, spark, commu...
# 2                                           [python]
# 3    [regress, python, commun, statist, sql, analyt]
# 4  [predict, regress, machin, engin, commun, pipe...

# %%
all("DS_JD.csv")
# Out:
#    Unnamed: 0                                  position            company  \
# 0           0                            Data Scientist         CVS Health
# 1           1  Part-Time Junior Data Scientist (Remote)          KBR, Inc.
# 2           2                            Data Scientist         CVS Health
# 3           3                            Data Scientist  Intel Corporation
# 4           4         Part-Time Data Scientist (Remote)          KBR, Inc.
#
#              location                                            details  \
# 0        New York, NY  Job Description\n\nDevelops, validates and exe...
# 1  Lexington Park, MD  Junior Data Scientist (Part-Time)\n\nSearching...
# 2        New York, NY  Job Description\n\nAt Aetna, a CVS Health comp...
# 3         Atlanta, GA  Job Description\n\nPlatform Security Engineeri...
# 4  Lexington Park, MD  Searching for a Data Scientist capable of lear...
#
#                                           newdetails  \
# 0  Develops validates executes algorithms predict...
# 1  Junior Data Scientist Searching data scientist...
# 2  Position Summary Aetna Clinical Analytics team...
# 3  Platform Security Engineering PSE small team S...
# 4  Searching Data Scientist capable learning inde...
#
#                             job_description_word_set  \
# 0  {analys, util, detail, abl, decis, data, form,...
# 1  {applic, servic, explain, capabl, contribut, d...
# 2  {analys, deep, detail, code, opportun, decis, ...
# 3  {anomali, applic, employ, creed, ordin, top, o...
# 4  {applic, servic, capabl, contribut, decis, tre...
#
#                                                   ba  \
# 0  [sourc, python, machin, commun, statist, sql, ...
# 1   [python, machin, scientist, statist, learn, sql]
# 2  [sourc, python, machin, scientist, commun, sta...
# 3                          [machin, statist, python]
# 4  [python, machin, scientist, statist, sql, analyt]
#
#                                                   da  \
# 0   [collect, machin, engin, sql, analyt, interpret]
# 1                           [scientist, machin, sql]
# 2  [collect, machin, scientist, sql, analyt, inte...
# 3                                    [engin, machin]
# 4                   [scientist, machin, sql, analyt]
#
#                                                   ds  \
# 0                 [machin, predict, python, statist]
# 1  [python, machin, scientist, quantit, statist, ...
# 2  [python, machin, scientist, statist, quantit, ...
# 3                          [machin, statist, python]
# 4  [python, machin, scientist, statist, quantit, ...
#
#                                   de  \
# 0  [engin, statist, python, pipelin]
# 1  [python, etl, aw, statist, cloud]
# 2         [statist, python, pipelin]
# 3           [engin, statist, python]
# 4  [python, etl, aw, statist, cloud]
#
#                                                  all
# 0  [collect, predict, sourc, python, machin, engi...
# 1  [python, learn, etl, machin, aw, scientist, qu...
# 2  [collect, predict, sourc, python, machin, scie...
# 3                   [engin, statist, machin, python]
# 4  [predict, python, etl, machin, aw, scientist, ...

# %%
all("DE_JD.csv")
# Out:
#    Unnamed: 0                                       position         company  \
# 0           0          Data Engineer, 1+ Years of Experience       Snap Inc.
# 1           1                           Senior Data Engineer        theSkimm
# 2           2              Sustainable Finance Data Engineer  Morgan Stanley
# 3           3  Data Engineer- Security Analytics & Reporting             IBM
# 4           4              NEED FOR DATA ENGINEER @ (REMOTE)            Dice
#
#         location                                            details  \
# 0   New York, NY  Snap Inc. is a camera company. We believe that...
# 1   New York, NY  theSkimm’\n\nWe’re hiring a Senior Data Engine...
# 2   New York, NY  The Global Sustainable Finance Group (GSF) aim...
# 3     Armonk, NY  526316BR\n\nIntroduction\n\nAs a Data Scientis...
# 4  United States  Dice is the leading career destination for tec...
#
#                                           newdetails  \
# 0  What You Do Work closely stakeholders engineer...
# 1  You responsible working alongside analysts pro...
# 2  The Global Sustainable Finance Group GSF aims ...
# 3  526316BR Introduction Work Best Class open sou...
# 4  JD AWS PAYTHON NAVEEN KUMAR mailto Direct 7329...
#
#                             job_description_word_set  \
# 0  {applic, ownership, adopt, portal, data, imple...
# 1  {employ, servic, child, new, guidanc, parent, ...
# 2  {applic, employ, effort, servic, york, reposit...
# 3  {applic, employ, scalabl, servic, retriev, par...
# 4  {kumar, jd, paython, 7329672703, aw, naveen, d...
#
#                                                   ba  \
# 0                                      [python, sql]
# 1                            [learn, commun, analyt]
# 2                      [machin, python, sql, analyt]
# 3  [sourc, python, scientist, commun, statist, sq...
# 4                                             [None]
#
#                                        da  \
# 0                            [engin, sql]
# 1         [collect, spark, analyt, engin]
# 2            [engin, machin, sql, analyt]
# 3  [excel, engin, scientist, sql, analyt]
# 4                                  [None]
#
#                                       ds                                 de  \
# 0                               [python]      [engin, python, pipelin, etl]
# 1                       [predict, learn]            [engin, spark, pipelin]
# 2              [machin, predict, python]     [engin, infrastructur, python]
# 3  [predict, python, statist, scientist]  [engin, statist, python, pipelin]
# 4                                 [None]                               [aw]
#
#                                                  all
# 0                 [python, etl, engin, pipelin, sql]
# 1  [collect, engin, spark, commun, pipelin, predi...
# 2  [python, machin, engin, infrastructur, predict...
# 3  [predict, sourc, python, excel, engin, scienti...
# 4                                               [aw]
