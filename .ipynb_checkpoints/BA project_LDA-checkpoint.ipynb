# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
df_BA=pd.read_csv('BA')
df_DS=pd.read_csv('DS')
df_DA=pd.read_csv('DA')
df_DE=pd.read_csv('DE')

# %%
df_DA=df_DA.sample(n = 500,replace=True)
df_BA=df_BA.sample(n = 500,replace=True)
df_DE=df_DE.sample(n = 500,replace=True)
df_DS=df_DS.sample(n = 500,replace=True)

# %%
len(df_DS),len(df_DA),len(df_BA),len(df_DE)
# Out:
# (500, 500, 500, 500)

# %%
whole_list=[df_DA,df_DS,df_DE,df_BA]
df_whole=pd.concat(whole_list).reset_index()
df_whole
# Out:
#       index  JT                                                 JD  \
# 0      1103  DA  This person will analyze quality and reliabili...
# 1      1692  DA  Are you passionate about data and technology?\...
# 2      2597  DA  POSITION SUMMARY:\nThe Billing Data Analyst wi...
# 3       681  DA  Additionally, you will collaborate with a mult...
# 4       815  DA  Position Summary:\nEssential Functions:\n·Prov...
# ...     ...  ..                                                ...
# 1995    562  BA  Join a team that combines state of the art tec...
# 1996   1335  BA  This individual will be a knowledge specialist...
# 1997    621  BA  Globally, the group’s over 44,000+ Professiona...
# 1998   1319  BA  The position requires a highly dedicated indiv...
# 1999    245  BA  Business Analyst\nEl Segundo\nPosition Overvie...
#
#                                               tool_list  \
# 0                                                [None]
# ...

# %%
print(df_whole['JD'].loc[550])
# Out:
# What about over the next five?
# Which product lines are poised to quintuple in size?
# The Topline Forecast team in the Supply Chain Optimization Technologies (SCOT) organization is dedicated to answering these questions using statistical methods.
# A successful candidate will be a problem solver who enjoys diving into data, is excited by difficult modeling challenges, and possesses strong communication skills to effectively interface between technical and business teams.
# Key Responsibilities:
# · Implement statistical methods to solve specific business problems utilizing code (Python, R, Scala, etc.).
# · Develop models and data-driven analyses to support strategic decisions
# · Improve upon existing methodologies by developing new data sources, testing model enhancements, and fine-tuning model parameters.
# · Directly contribute to the design and development of automated forecasting systems.
# ...

# %%
for i in df_whole.index:
    row = df_whole.loc[i]
    row['JD'].replace('\n','')
    row['JD'].replace('Business Analyst','')
    row['JD'].replace('Data Analyst','')
    row['JD'].replace('Data Engineer','')
    row['JD'].replace('Data Science','')

# %%
BA_list = list()
count = 0
for i in df_whole.index:
    row = df_whole.loc[i]
    if row['JT'] == 'BA':
        text = row['JD'].strip()
        BA_list.append(text)

# %%
BA_list
# Out:
# ['Business Analyst / ERP Business Analyst\nLos Angeles, CA\n4 position\n6 month Contract to Hire\nRequirements\nBusiness Analyst will need to be able to design, test, and support system users in the human resources industry.\nUltimately, the business analyst will collaborate with the client on technology and business process related efforts that include gathering functional business requirements, designing new system functionality, testing software code, setting up security and workflow, and supporting end users.\nERP Business Analyst will need to be able to design, configure, test, and implement the Advantage ERP software for clients.\nUltimately, the business analyst will collaborate with the client on technology and business process related efforts for the implementation of the HR system, which include gathering functional business requirements, designing/configuring new system functionality, testing software code, and supporting end users.\nRequired qualifications to be successfu
# ...

# %%
# do the LDA
from gensim import corpora
from gensim.models.ldamodel import LdaModel
from gensim.parsing.preprocessing import STOPWORDS
import pprint

# %%
# prepare for the text
import nltk
nltk.download('punkt')
from nltk import sent_tokenize,word_tokenize 
for i in range(len(BA_list)):
    JD = BA_list[i]
    sents = sent_tokenize(JD)
    for j in range(len(sents)):
        sent = sents[j]
        sent = sent.strip().replace('\n','')
        sents[j] = sent
    BA_list[i] = '. '.join(sents)
# Out:
# [nltk_data] Downloading package punkt to /Users/nanliao/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
BA_list
# Out:
# ['Business Analyst / ERP Business AnalystLos Angeles, CA4 position6 month Contract to HireRequirementsBusiness Analyst will need to be able to design, test, and support system users in the human resources industry.. Ultimately, the business analyst will collaborate with the client on technology and business process related efforts that include gathering functional business requirements, designing new system functionality, testing software code, setting up security and workflow, and supporting end users.. ERP Business Analyst will need to be able to design, configure, test, and implement the Advantage ERP software for clients.. Ultimately, the business analyst will collaborate with the client on technology and business process related efforts for the implementation of the HR system, which include gathering functional business requirements, designing/configuring new system functionality, testing software code, and supporting end users.. Required qualifications to be successful in this 
# ...

# %%
texts = [[word for word in JD.lower().split()
        if word not in STOPWORDS and word.isalnum()]
        for JD in BA_list]
texts[1]
# Out:
# ['interested',
#  'email',
#  'copy',
#  'resume',
#  'salary',
#  'expectations',
#  'darton',
#  'data',
#  'vba',
#  'macrounderstand',
#  'ms',
#  'sql',
#  'server',
#  'db',
#  'structure',
#  'queries',
#  'sql',
#  'dbs',
#  'based',
#  'business',
#  'needscreate',
#  'output',
#  'tools',
#  'receive',
#  'business',
#  'requirements',
#  'start',
#  'programmingunderstand',
#  'concepts',
#  'bi',
#  'data',
#  'analytics',
#  'years',
#  'experience',
#  'similar',
#  'data',
#  'focused',
#  'analytical',
#  'years',
#  'degree',
#  'preferredexperience',
#  'gathering',
#  'requirements',
#  'writing',
#  'technical',
#  'specificationsdata',
#  'visualization',
#  'years',
#  'experience',
#  'sql',
#  'vba']

# %%
dictionary = corpora.Dictionary(texts) #(word_id,word) pairs
corpus = [dictionary.doc2bow(text) for text in texts] #(word_id,freq) pairs by sentence

# %%
num_topics = 3 #The number of topics that should be generated
passes = 10

# %%
lda = LdaModel(corpus,
              id2word=dictionary,
              num_topics=num_topics,
              passes=passes)

# %%
pp = pprint.PrettyPrinter(indent=4)
pp.pprint(lda.print_topics(num_words=5))# use 5 words to describe the topic
# Out:
# [   (   0,
#         '0.020*"business" + 0.014*"experience" + 0.010*"work" + '
#         '0.007*"ability" + 0.006*"development"'),
#     (   1,
#         '0.040*"business" + 0.016*"experience" + 0.013*"requirements" + '
#         '0.013*"data" + 0.012*"project"'),
#     (   2,
#         '0.034*"business" + 0.012*"experience" + 0.010*"work" + 0.009*"data" + '
#         '0.009*"requirements"')]

# %%
lda.show_topic(0)
# Out:
# [('business', 0.01970824),
#  ('experience', 0.013548866),
#  ('work', 0.009602831),
#  ('ability', 0.0068847486),
#  ('development', 0.0064024017),
#  ('working', 0.0062776133),
#  ('user', 0.0059065293),
#  ('management', 0.0057275575),
#  ('project', 0.005572942),
#  ('skills', 0.00548571)]
