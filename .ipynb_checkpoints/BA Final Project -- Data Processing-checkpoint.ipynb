# %%
import pandas as pd
import numpy as np
import re
from nltk import sent_tokenize,word_tokenize

# %% [markdown]
# # Data Cleaning

# %%
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name
clean=["we","our","us","itself","employees","firm","apply","disabilities",
       "re","company","description","accomendation","\nWe","relocation","location"]
def clean_JD(jd,name):
    if len(name)>1:
        s=""
        try:
            for i in name:
                s+=i[0]
            name+=[s]
        except:
            pass
    res=""
    for sentence in sent_tokenize(jd):
        for j in sentence.split("\n"):
            if not j: continue
            sent=[]
            for x in word_tokenize(j):
                if x.isalnum():
                    sent.append(x.lower())
            A=set(sent)
            B=set(name+clean)
            if not A&B:
                res+=j+"\n"
    return res if res else None
def split_by_slash(a):
    if str(a).find("\n")!=-1:
        a = a.split("\n")[0]
    a=a.replace("-"," ")
    return [x.lower() for x in word_tokenize(a) if x.isalnum()]

# %%
def data_clean(df):
    name = get_df_name(df)
    checklist={"BA":"Business Analyst","DA":"Data Analyst","DE":"Data Engineer","DS":"Data Scientist"}
    df=df.rename(columns={"Job Title":"JT","Job Description":"JD","Salary Estimate":"Salary"})
    
    #filter out columns that do not have role title in the name
    df=df[df.JT.str.contains(checklist[name], regex= True, na=False)]
    df=df[["JT","Salary","JD","Company Name"]]
    
    #get name
    df["Company Name"] =df.apply(lambda x: split_by_slash(x['Company Name']),axis=1)
    #filter out sentences in JD that has the company name or common words 
    df['JD'] =df.apply(lambda x: clean_JD(x['JD'],x['Company Name']),axis=1)

    df=df.dropna()
    df.reset_index(inplace=True)
    return df

# %% [markdown]
# # BA Dataset

# %%
BA = pd.read_csv("BusinessAnalyst.csv")
part1=BA[:3691]
part1.drop("Unnamed: 0" , axis=1, inplace=True)
part1.drop("index" , axis=1, inplace=True)
part2=BA[3692:]
part2.columns=["Job Title","Salary Estimate","Job Description","Rating","Company Name","Location","Headquarters","Size","Founded","Type of ownership","Industry","Sector","Revenue","Competitors","Easy Apply","A","B"]
part2.drop("A" , axis=1, inplace=True)
part2.drop("B" , axis=1, inplace=True)
BA=pd.concat([part1,part2])
# Out:
# /Users/lisakuai/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df_BA=data_clean(BA)

# %%
df_BA
# Out:
#       index                                                 JT  \
# 0         0   Business Analyst - Clinical & Logistics Platform
# 1         1                                   Business Analyst
# 2         8                           Tolling Business Analyst
# 3         9                            Business Analyst - Risk
# 4        14                                   Business Analyst
# ...     ...                                                ...
# 1658   3931                           Business Analyst Fresher
# 1659   3935  SAS Developer and Business Analyst (Security/F...
# 1660   3966              Business Analyst - Loan IQ Specialist
# 1661   4014                           Business Analyst Fresher
# 1662   4052                  Urgent - Business Analyst Fresher
#
#                            Salary  \
# 0     $56K-$102K (Glassdoor est.)
# 1     $56K-$102K (Glassdoor est.)
# 2     $56K-$102K (Glassdoor est.)
# 3     $56K-$102K (Glassdoor est.)
# 4     $56K-$102K (Glassdoor est.)
# ...                           ...
# 1658  $45K-$110K (Glassdoor est.)
# 1659   $30K-$57K (Glassdoor est.)
# 1660   $28K-$54K (Glassdoor est.)
# 1661  $47K-$105K (Glassdoor est.)
# 1662   $39K-$73K (Glassdoor est.)
#
#                                                      JD  \
# 0     You will:\nSupport agile team in translating e...
# 1     If you enjoy working in a highly collaborative...
# 2     Excellence Delivered As Promised.\nIt’s more t...
# 3     This global practice supports clients in many ...
# 4     Business Analysts roles are targeted at gradua...
# ...                                                 ...
# 1658  Junior Business Analyst\nAs the Business Analy...
# 1659  The Business Senior Analyst is an intermediate...
# 1660  Back to job search\nBusiness Analyst - Loan IQ...
# 1661  Junior Business Analyst\nAs the Business Analy...
# 1662  Junior Business Analyst\nAs the Business Analy...
#
#                                            Company Name
# 0                     [memorial, sloan, kettering, msk]
# 1                      [paine, schwartz, partners, psp]
# 2                                [gannett, fleming, gf]
# 3                                            [mckinsey]
# 4                                             [efficio]
# ...                                                 ...
# 1658         [staffigo, technical, services, llc, stsl]
# 1659                                         [citibank]
# 1660  [delaware, investments, colorado, municipal, i...
# 1661         [staffigo, technical, services, llc, stsl]
# 1662         [staffigo, technical, services, llc, stsl]
#
# [1663 rows x 5 columns]

# %% [markdown]
# # DA Dataset

# %%
DA=pd.read_csv("DataAnalyst.csv")
DA=DA.dropna()

# %%
df_DA=data_clean(DA)

# %%
df_DA
# Out:
#       index                                                 JT  \
# 0         0  Data Analyst, Center on Immigration and Justic...
# 1         1                               Quality Data Analyst
# 2         2  Senior Data Analyst, Insights & Analytics Team...
# 3         3                                       Data Analyst
# 4         4                             Reporting Data Analyst
# ...     ...                                                ...
# 3978   5626                      Data Analyst (Power BI + SAP)
# 3979   5627                 Technical Business or Data Analyst
# 3980   5628                                Data Analyst Junior
# 3981   5629                                Sr. HR Data Analyst
# 3982   5630                              Data Analyst â Junior
#
#                            Salary  \
# 0      $37K-$66K (Glassdoor est.)
# 1      $37K-$66K (Glassdoor est.)
# 2      $37K-$66K (Glassdoor est.)
# 3      $37K-$66K (Glassdoor est.)
# 4      $37K-$66K (Glassdoor est.)
# ...                           ...
# 3978   $51K-$93K (Glassdoor est.)
# 3979   $46K-$72K (Glassdoor est.)
# 3980   $44K-$82K (Glassdoor est.)
# 3981   $44K-$82K (Glassdoor est.)
# 3982  $89K-$151K (Glassdoor est.)
#
#                                                      JD  \
# 0     Are you eager to roll up your sleeves and harn...
# 1     Overview\nProvides support and analytical insi...
# 2     In this role, you’ll have the opportunity to b...
# 3     Requisition NumberRR-0001939\nRemote:Yes\nIntr...
# 4     TVG — The best-in-class horse racing TV/media ...
# ...                                                 ...
# 3978  This dynamic role will require the candidate t...
# 3979  Hi\nHope you are doing great\nPlease go throug...
# 3980  Interpret data, analyze results using statisti...
# 3981  POSITION SUMMARY:\nThey will also analyze data...
# 3982  Interpret data, analyze results using statisti...
#
#                                            Company Name
# 0                  [vera, institute, of, justice, vioj]
# 1     [visiting, nurse, service, of, new, york, vnsony]
# 2                                         [squarespace]
# 3                                            [celerity]
# 4                                             [fanduel]
# ...                                                 ...
# 3978                          [kore1, technologies, kt]
# 3979                            [adwait, algorithm, aa]
# 3980         [staffigo, technical, services, llc, stsl]
# 3981                                          [cepheid]
# 3982         [staffigo, technical, services, llc, stsl]
#
# [3983 rows x 5 columns]

# %% [markdown]
# # Data Scientist

# %%
DS=pd.read_csv("DataScientist.csv")

# %%
df_DS=data_clean(DS)

# %%
df_DS
# Out:
#      index                                                 JT  \
# 0        0                              Senior Data Scientist
# 1        1                  Data Scientist, Product Analytics
# 2        5                                     Data Scientist
# 3       10                                     Data Scientist
# 4       11                    Data Scientist/Machine Learning
# ..     ...                                                ...
# 968   3804                            Senior Data Scientist *
# 969   3809                              Data Scientist - BFSI
# 970   3818                Sr. Data Scientist (Columbus, Ohio)
# 971   3819  Data Scientist Lead, Capacity Planning & Analy...
# 972   3830                  Principal Data Scientist, Pricing
#
#                            Salary  \
# 0    $111K-$181K (Glassdoor est.)
# 1    $111K-$181K (Glassdoor est.)
# 2    $111K-$181K (Glassdoor est.)
# 3    $111K-$181K (Glassdoor est.)
# 4    $111K-$181K (Glassdoor est.)
# ..                            ...
# 968    $52K-$94K (Glassdoor est.)
# 969    $52K-$94K (Glassdoor est.)
# 970    $52K-$94K (Glassdoor est.)
# 971    $52K-$94K (Glassdoor est.)
# 972   $55K-$113K (Glassdoor est.)
#
#                                                     JD  \
# 0    The app has received high praise in the form o...
# 1    You have 4+ years of experience as a Data Scie...
# 2    Job Brief\nThe ideal candidate will have previ...
# 3    Backed by $153MM in venture funding from top i...
# 4    PulsePoint™, a global programmatic advertising...
# ..                                                 ...
# 968  There is no shortage of computational and stat...
# 969  Good understanding of machine learning and dat...
# 970  You will collaborate with cross-functional tea...
# 971  The Business Planning and Analysis (BP&A) team...
# 972  The ideal candidate will have experience in Pr...
#
#                      Company Name
# 0                        [hopper]
# 1                  [noom, us, nu]
# 2            [ifg, companies, ic]
# 3           [quartet, health, qh]
# 4                    [pulsepoint]
# ..                            ...
# 968         [root, insurance, ri]
# 969             [tephra, inc, ti]
# 970        [tiger, analytics, ta]
# 971  [jpmorgan, chase, bank, jcb]
# 972         [root, insurance, ri]
#
# [973 rows x 5 columns]

# %% [markdown]
# # Data Engineer

# %%
DE=pd.read_csv("DataEngineer.csv")

# %%
df_DE=data_clean(DE)

# %%
df_DE
# Out:
#       index                                                 JT  \
# 0         0                                      Data Engineer
# 1         1  Senior Data Engineer (Healthcare Domain experi...
# 2         2                                     Data Engineers
# 3         4                                      Data Engineer
# 4         6                               Senior Data Engineer
# ...     ...                                                ...
# 1162   2500                   Federal - Data Engineer - Senior
# 1163   2503                            Sr Data Engineer Hadoop
# 1164   2504                           Senior Big Data Engineer
# 1165   2514                  Digital SW Eng Lead/Data Engineer
# 1166   2525                              Sr. Big Data Engineer
#
#                            Salary  \
# 0     $80K-$150K (Glassdoor est.)
# 1     $80K-$150K (Glassdoor est.)
# 2     $80K-$150K (Glassdoor est.)
# 3     $80K-$150K (Glassdoor est.)
# 4     $80K-$150K (Glassdoor est.)
# ...                           ...
# 1162   $56K-$89K (Glassdoor est.)
# 1163   $56K-$89K (Glassdoor est.)
# 1164   $56K-$89K (Glassdoor est.)
# 1165  $76K-$128K (Glassdoor est.)
# 1166  $76K-$128K (Glassdoor est.)
#
#                                                      JD  \
# 0     **\nJob Overview\nAlong with the requirements ...
# 1     Key Responsibilities\n- Architect, build, and ...
# 2     Overview\nPosition Overview:\nSeeking a highly...
# 3     Data Engineer\nJob Details\nLevel\nExperienced...
# 4     Senior Data Engineer\nMaster’s degree in Infor...
# ...                                                 ...
# 1162  Organization: Accenture Federal Services\nAcce...
# 1163  Job Responsibilities\nWrite well designed, tes...
# 1164  Your Opportunity\nThey help Marketing, Finance...
# 1165  Digital SW Eng Lead/Data Engineer\nIrving, TX\...
# 1166  Develop data collections, labeling pipelines, ...
#
#                                          Company Name
# 0                                           [sagence]
# 1                       [enterprise, integration, ei]
# 2                         [maestro, technologies, mt]
# 3                    [gny, insurance, companies, gic]
# 4                           [affinity, solutions, as]
# ...                                               ...
# 1162                    [solekai, systems, corp, ssc]
# 1163                                  [ntt, data, nd]
# 1164                                         [schwab]
# 1165                     [technocraft, solutions, ts]
# 1166  [cincinnati, bell, technology, solutions, cbts]
#
# [1167 rows x 5 columns]

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt
def wc(df):    
    res=""
    for i,row in df.iterrows():
        res+=row['JD']
    # %matplotlib inline
    wordcloud = WordCloud(stopwords=STOPWORDS,background_color='white',width=3000,height=3000).generate(res)


    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-16-a0ca0baa2c84> in <module>
# ----> 1 from wordcloud import WordCloud, STOPWORDS
#       2 import matplotlib.pyplot as plt
#       3 def wc(df):
#       4     res=""
#       5     for i,row in df.iterrows():
#
# ModuleNotFoundError: No module named 'wordcloud'

# %%
wc(df_BA)

# %%
wc(df_DA)

# %%
wc(df_DS)

# %%
wc(df_DE)

# %% [markdown]
# # JD List Matching

# %%
from collections import Counter
import nltk
import string
from nltk.tokenize import word_tokenize
import math

# %%
# got these keywords by looking at some examples and using existing knowledge.
tool_keywords1 = ['python', 'pytorch', 'sql', 'mxnet', 'mlflow', 'einstein', 'theano', 'pyspark', 'solr', 'mahout', 
 'cassandra', 'aws', 'powerpoint', 'spark', 'pig', 'sas', 'java', 'nosql', 'docker', 'salesforce', 'scala', 'r',
 'c', 'c++', 'net', 'tableau', 'pandas', 'scikitlearn', 'sklearn', 'matlab','keras', 'tensorflow', 'clojure',
 'caffe', 'scipy', 'numpy', 'matplotlib', 'vba', 'spss', 'linux', 'azure', 'cloud', 'gcp', 'mongodb', 'mysql', 'oracle', 
 'redshift', 'snowflake', 'kafka', 'javascript', 'qlik', 'jupyter', 'perl', 'bigquery', 'unix', 'react',
 'scikit', 'powerbi', 's3', 'ec2', 'lambda', 'ssrs', 'kubernetes', 'hana', 'spacy', 'tf', 'django', 'sagemaker',
 'seaborn', 'mllib', 'github', 'git', 'elasticsearch', 'splunk', 'airflow', 'looker', 'rapidminer', 'birt', 'pentaho', 
 'jquery', 'nodejs', 'd3', 'plotly', 'bokeh', 'xgboost', 'rstudio', 'shiny', 'dash', 'h20', 'h2o', 'hadoop', 'mapreduce', 
 'hive', 'cognos', 'angular', 'nltk', 'flask', 'node', 'firebase', 'bigtable', 'rust', 'php', 'cntk', 'lightgbm', 
 'kubeflow', 'rpython', 'unixlinux', 'postgressql', 'postgresql', 'postgres', 'hbase', 'dask', 'ruby', 'julia', 'tensor',
# added r packages doesn't seem to impact the result
 'dplyr','ggplot2','esquisse','bioconductor','shiny','lubridate','knitr','mlr','quanteda','dt','rcrawler','caret','rmarkdown',
 'leaflet','janitor','ggvis','plotly','rcharts','rbokeh','broom','stringr','magrittr','slidify','rvest',
 'rmysql','rsqlite','prophet','glmnet','text2vec','snowballc','quantmod','rstan','swirl','datasciencer',
'c#','excel','microsoft','erp','tableau','vba','jira','git','postgresql','db','bi']


# another set of keywords that are longer than one word.
tool_keywords2 = set(['amazon web services', 'google cloud','power bi','erp system','ms office'])

# %%
# hard skills/knowledge required.
skill_keywords1 = set(['statistics', 'cleansing', 'chatbot', 'cleaning', 'blockchain', 'causality', 'correlation', 'bandit', 'anomaly', 'kpi',
 'dashboard', 'geospatial', 'ocr', 'econometrics', 'pca', 'gis', 'svm', 'svd', 'tuning', 'hyperparameter', 'hypothesis',
 'salesforcecom', 'segmentation', 'biostatistics', 'unsupervised', 'supervised', 'exploratory',
 'recommender', 'recommendations','sequencing', 'probability', 'reinforcement', 'graph', 'bioinformatics',
 'chi', 'knn', 'outlier', 'etl', 'normalization', 'classification', 'optimizing', 'prediction', 'forecasting',
 'clustering', 'cluster', 'optimization', 'visualization', 
 'regression', 'logistic', 'nn', 'cnn', 'glm','nlp','economics','math','engineering'
 'rnn', 'lstm', 'gbm', 'boosting', 'recurrent', 'convolutional', 'bayesian','analyze','research','data','business',
'healthcare','risk','finance','accounting','hardware','pipeline','communication',
 'bayes'])


# another set of keywords that are longer than one word.
skill_keywords2 = set(['random forest', 'natural language processing', 'machine learning', 'decision tree', 'deep learning', 'experimental design',
 'time series', 'nearest neighbors', 'neural network', 'support vector machine', 'computer vision', 'dimensionality reduction', 
 'text analytics', 'a b testing', 'ab testing', 'chat bot', 'data mining','problem solving','project management'
'computer science','information technology','data modeling', 'data warehousing','end user',
'financial modeling','multivariate testing','database deployment','big data'])

# %%
degree_dict = {'bs': 1, 'bachelor': 1, 'undergraduate': 1, 
               'master': 2, 'graduate': 2, 'mba': 2.5, 
               'phd': 3, 'ph.d': 3, 'ba': 1, 'ma': 2,
               'postdoctoral': 4, 'postdoc': 4, 'doctorate': 3}


degree_dict2 = {'advanced degree': 2, 'ms or': 2, 'ms degree': 2, '4 year degree': 1, 'bs/': 1, 'ba/': 1,
                '4-year degree': 1, 'b.s.': 1, 'm.s.': 2, 'm.s': 2, 'b.s': 1, 'phd/': 3, 'ph.d.': 3, 'ms/': 2,
                'm.s/': 2, 'm.s./': 2, 'msc/': 2, 'master/': 2, 'master\'s/': 2, 'bachelor\s/': 1}
degree_keywords2 = set(degree_dict2.keys())

# %%
from nltk import pos_tag
from nltk.stem import PorterStemmer

ps = PorterStemmer()

# process the keywords
tool_keywords1_set = set([ps.stem(tok) for tok in tool_keywords1]) # stem the keywords (since the job description is also stemmed.)
tool_keywords1_dict = {ps.stem(tok):tok for tok in tool_keywords1} # use this dictionary to revert the stemmed words back to the original.

skill_keywords1_set = set([ps.stem(tok) for tok in skill_keywords1])
skill_keywords1_dict = {ps.stem(tok):tok for tok in skill_keywords1}

degree_keywords1_set = set([ps.stem(tok) for tok in degree_dict.keys()])
degree_keywords1_dict = {ps.stem(tok):tok for tok in degree_dict.keys()}

# %%
# process the job description.
def prepare_job_desc(desc):
    # tokenize description.
    desc=desc.replace("-"," ")
    desc=desc.replace("/"," ")
    tokens = [x for x in word_tokenize(desc) if x.isalnum()]
        
    # Parts of speech (POS) tag tokens.
    token_tag = pos_tag(tokens)
    
    # Only include some of the POS tags.
    include_tags = ['VBN', 'VBD', 'JJ', 'JJS', 'JJR', 'CD', 'NN', 'NNS', 'NNP', 'NNPS']
    filtered_tokens = [tok for tok, tag in token_tag if tag in include_tags]
    
    # stem words.
    stemmed_tokens = [ps.stem(tok).lower() for tok in filtered_tokens]
    return set(stemmed_tokens)

# %%
def mapping_list(df):
    name=get_df_name(df)
    df['JT']=name.split("_")[1]
    df['job_description_word_set'] =df['JD'].map(prepare_job_desc)
    
    tool_list = []
    skill_list = []
    degree_list = []

    num_postings = len(df.index)
    for i in range(num_postings):
        job_desc = df.iloc[i]['JD'].lower()
        job_desc_set = df.iloc[i]['job_description_word_set']

        # check if the keywords are in the job description. Look for exact match by token.
        tool_words = tool_keywords1_set.intersection(job_desc_set)
        skill_words = skill_keywords1_set.intersection(job_desc_set)
        degree_words = degree_keywords1_set.intersection(job_desc_set)

        # check if longer keywords (more than one word) are in the job description. Match by substring.
        j = 0
        for tool_keyword2 in tool_keywords2:
            # tool keywords.
            if tool_keyword2 in job_desc:
                tool_words.add(tool_keyword2)
                j += 1

        k = 0
        for skill_keyword2 in skill_keywords2:
            # skill keywords.
            if skill_keyword2 in job_desc:
                skill_words.add(skill_keyword2)
                k += 1

        # search for the minimum education.
        min_education_level = 999
        for degree_word in degree_words:
            level = degree_dict[degree_keywords1_dict[degree_word]]
            min_education_level = min(min_education_level, level)

        for degree_keyword2 in degree_keywords2:
            # longer keywords. Match by substring.
            if degree_keyword2 in job_desc:
                level = degree_dict2[degree_keyword2]
                min_education_level = min(min_education_level, level)

        # label the job descriptions without any tool keywords.
        if len(tool_words) == 0 and j == 0:
            tool_words=[None]

        # label the job descriptions without any skill keywords.
        if len(skill_words) == 0 and k == 0:
            skill_words=[None]

        # If none of the keywords were found, but the word degree is present, then assume it's a bachelors level.
        if min_education_level > 500:
            if 'degree' in job_desc:
                min_education_level = 1
                
        tool_list.append(list(tool_words))
        skill_list.append(list(skill_words))
        degree_list.append(min_education_level)
    return tool_list, skill_list, degree_list

# %%
def df_with_feature(df):
    tool_list, skill_list, degree_list=mapping_list(df)
    df["tool_list"]=tool_list
    df["skill_list"]=skill_list
    df["degree_list"]=degree_list
    return df

# %%
same_words={
    'amazon web services':'aw',
    'postgr':'sql',
    'mysql':'sql',
    'natural language processing':'nlp',
    #'nltk':'nlp'
    'power bi':'powerbi',
    'bi':'powerbi',
    'rstudio':'r',
    'neural network':'nn',
    'support vector machine':'svm',
    'a b testing':'ab testing',
    'ms office':'microsoft'
}
def combine1(tool,skill):
    res=[]

    new=tool+skill
    for word in new:
        if word!=None:
            if word in same_words:
                    if same_words[word] not in res:
                        res.append(same_words[word])
            else:
                res.append(word)
    return res

def new_list(df):
    df=df_with_feature(df)
    df["clean"] =df.apply(lambda x: combine1(x['tool_list'],x['skill_list']),axis=1)
    return df

# %% [markdown]
# # Final DataSet

# %%
df_BA=new_list(df_BA)
df_BA
# Out:
#       index  JT                       Salary  \
# 0         0  BA  $56K-$102K (Glassdoor est.)
# 1         1  BA  $56K-$102K (Glassdoor est.)
# 2         8  BA  $56K-$102K (Glassdoor est.)
# 3         9  BA  $56K-$102K (Glassdoor est.)
# 4        14  BA  $56K-$102K (Glassdoor est.)
# ...     ...  ..                          ...
# 1658   3931  BA  $45K-$110K (Glassdoor est.)
# 1659   3935  BA   $30K-$57K (Glassdoor est.)
# 1660   3966  BA   $28K-$54K (Glassdoor est.)
# 1661   4014  BA  $47K-$105K (Glassdoor est.)
# 1662   4052  BA   $39K-$73K (Glassdoor est.)
#
#                                                      JD  \
# 0     You will:\nSupport agile team in translating e...
# 1     If you enjoy working in a highly collaborative...
# 2     Excellence Delivered As Promised.\nIt’s more t...
# 3     This global practice supports clients in many ...
# 4     Business Analysts roles are targeted at gradua...
# ...                                                 ...
# 1658  Junior Business Analyst\nAs the Business Analy...
# 1659  The Business Senior Analyst is an intermediate...
# 1660  Back to job search\nBusiness Analyst - Loan IQ...
# 1661  Junior Business Analyst\nAs the Business Analy...
# 1662  Junior Business Analyst\nAs the Business Analy...
#
#                                            Company Name  \
# 0                     [memorial, sloan, kettering, msk]
# 1                      [paine, schwartz, partners, psp]
# 2                                [gannett, fleming, gf]
# 3                                            [mckinsey]
# 4                                             [efficio]
# ...                                                 ...
# 1658         [staffigo, technical, services, llc, stsl]
# 1659                                         [citibank]
# 1660  [delaware, investments, colorado, municipal, i...
# 1661         [staffigo, technical, services, llc, stsl]
# 1662         [staffigo, technical, services, llc, stsl]
#
#                                job_description_word_set            tool_list  \
# 0     {research, increment, informat, group, close, ...              [excel]
# 1     {industri, integr, financ, posit, dynam, path,...   [salesforc, excel]
# 2     {research, industri, support, client, improv, ...              [excel]
# 3     {client, industri, support, research, assign, ...               [None]
# 4     {client, fact, entri, experienc, supplier, eco...  [excel, powerpoint]
# ...                                                 ...                  ...
# 1658  {collabor, matter, team, liaison, accuraci, an...               [None]
# 1659  {support, variou, posit, equival, challeng, co...          [sa, excel]
# 1660  {client, 949535, group, corpor, financ, posit,...              [excel]
# 1661  {collabor, matter, team, liaison, accuraci, an...               [None]
# 1662  {collabor, matter, team, liaison, accuraci, an...               [None]
#
#                                              skill_list  degree_list  \
# 0     [research, account, end user, analyz, commun, ...          1.0
# 1         [account, econom, visual, financ, busi, data]          1.0
# 2     [research, statist, recommend, kpi, econom, vi...          1.0
# 3     [research, statist, recommend, econom, math, f...          1.0
# 4     [recommend, econom, commun, problem solving, b...          1.0
# ...                                                 ...          ...
# 1658                                     [busi, analyz]        999.0
# 1659     [account, commun, problem solving, busi, data]          1.0
# 1660              [account, commun, financ, risk, busi]        999.0
# 1661                                     [busi, analyz]        999.0
# 1662                                     [busi, analyz]        999.0
#
#                                                   clean
# 0     [excel, research, account, end user, analyz, c...
# 1     [salesforc, excel, account, econom, visual, fi...
# 2     [excel, research, statist, recommend, kpi, eco...
# 3     [research, statist, recommend, econom, math, f...
# 4     [excel, powerpoint, recommend, econom, commun,...
# ...                                                 ...
# 1658                                     [busi, analyz]
# 1659  [sa, excel, account, commun, problem solving, ...
# 1660       [excel, account, commun, financ, risk, busi]
# 1661                                     [busi, analyz]
# 1662                                     [busi, analyz]
#
# [1663 rows x 10 columns]

# %%
df_DA=new_list(df_DA)
df_DA
# Out:
#       index  JT                       Salary  \
# 0         0  DA   $37K-$66K (Glassdoor est.)
# 1         1  DA   $37K-$66K (Glassdoor est.)
# 2         2  DA   $37K-$66K (Glassdoor est.)
# 3         3  DA   $37K-$66K (Glassdoor est.)
# 4         4  DA   $37K-$66K (Glassdoor est.)
# ...     ...  ..                          ...
# 3978   5626  DA   $51K-$93K (Glassdoor est.)
# 3979   5627  DA   $46K-$72K (Glassdoor est.)
# 3980   5628  DA   $44K-$82K (Glassdoor est.)
# 3981   5629  DA   $44K-$82K (Glassdoor est.)
# 3982   5630  DA  $89K-$151K (Glassdoor est.)
#
#                                                      JD  \
# 0     Are you eager to roll up your sleeves and harn...
# 1     Overview\nProvides support and analytical insi...
# 2     In this role, you’ll have the opportunity to b...
# 3     Requisition NumberRR-0001939\nRemote:Yes\nIntr...
# 4     TVG — The best-in-class horse racing TV/media ...
# ...                                                 ...
# 3978  This dynamic role will require the candidate t...
# 3979  Hi\nHope you are doing great\nPlease go throug...
# 3980  Interpret data, analyze results using statisti...
# 3981  POSITION SUMMARY:\nThey will also analyze data...
# 3982  Interpret data, analyze results using statisti...
#
#                                            Company Name  \
# 0                  [vera, institute, of, justice, vioj]
# 1     [visiting, nurse, service, of, new, york, vnsony]
# 2                                         [squarespace]
# 3                                            [celerity]
# 4                                             [fanduel]
# ...                                                 ...
# 3978                          [kore1, technologies, kt]
# 3979                            [adwait, algorithm, aa]
# 3980         [staffigo, technical, services, llc, stsl]
# 3981                                          [cepheid]
# 3982         [staffigo, technical, services, llc, stsl]
#
#                                job_description_word_set  \
# 0     {dataset, research, unaccompani, support, 212,...
# 1     {research, support, stata, entri, concentr, qa...
# 2     {rais, dataset, curios, organiz, scientist, mo...
# 3     {client, support, 19, posit, multidimension, p...
# 4     {support, 1, allow, posit, premier, hors, repo...
# ...                                                 ...
# 3978  {industri, sla, assign, organiz, spreadsheet, ...
# 3979  {w2, lost, uat, analyst, pleas, platform, inte...
# 3980  {dataset, wz7o3zfw27, improv, prefer, report, ...
# 3981  {standard, support, assign, improv, integr, ac...
# 3982  {dataset, improv, prefer, report, problem, sci...
#
#                                               tool_list  \
# 0                     [sql, r, git, python, aw, github]
# 1            [sa, sql, r, excel, microsoft, powerpoint]
# 2                 [sql, r, looker, python, bi, tableau]
# 3                               [sql, tableau, powerbi]
# 4                                  [python, excel, sql]
# ...                                                 ...
# 3978  [sql, r, excel, powerbi, bi, microsoft, power ...
# 3979                                   [sql, aw, cloud]
# 3980                 [sa, sql, spss, excel, javascript]
# 3981                        [excel, microsoft, powerbi]
# 3982                 [sa, sql, spss, excel, javascript]
#
#                                              skill_list  degree_list  \
# 0     [research, dashboard, clean, anomali, data, st...        999.0
# 1     [research, statist, dashboard, recommend, anal...          1.0
# 2     [text analytics, natural language processing, ...          1.0
# 3          [etl, recommend, visual, commun, busi, data]          1.0
# 4                                        [visual, data]          1.0
# ...                                                 ...          ...
# 3978  [dashboard, account, kpi, end user, visual, co...        999.0
# 3979                                       [busi, data]          1.0
# 3980          [etl, clean, data, analyz, busi, statist]          2.0
# 3981  [recommend, dashboard, kpi, problem solving, b...          1.0
# 3982                 [etl, data, analyz, busi, statist]          2.0
#
#                                                   clean
# 0     [sql, r, git, python, aw, github, research, da...
# 1     [sa, sql, r, excel, microsoft, powerpoint, res...
# 2     [sql, r, looker, python, powerbi, tableau, tex...
# 3     [sql, tableau, powerbi, etl, recommend, visual...
# 4                    [python, excel, sql, visual, data]
# ...                                                 ...
# 3978  [sql, r, excel, powerbi, microsoft, powerpoint...
# 3979                       [sql, aw, cloud, busi, data]
# 3980  [sa, sql, spss, excel, javascript, etl, clean,...
# 3981  [excel, microsoft, powerbi, recommend, dashboa...
# 3982  [sa, sql, spss, excel, javascript, etl, data, ...
#
# [3983 rows x 10 columns]

# %%
df_DS=new_list(df_DS)
df_DS
# Out:
#      index  JT                        Salary  \
# 0        0  DS  $111K-$181K (Glassdoor est.)
# 1        1  DS  $111K-$181K (Glassdoor est.)
# 2        5  DS  $111K-$181K (Glassdoor est.)
# 3       10  DS  $111K-$181K (Glassdoor est.)
# 4       11  DS  $111K-$181K (Glassdoor est.)
# ..     ...  ..                           ...
# 968   3804  DS    $52K-$94K (Glassdoor est.)
# 969   3809  DS    $52K-$94K (Glassdoor est.)
# 970   3818  DS    $52K-$94K (Glassdoor est.)
# 971   3819  DS    $52K-$94K (Glassdoor est.)
# 972   3830  DS   $55K-$113K (Glassdoor est.)
#
#                                                     JD  \
# 0    The app has received high praise in the form o...
# 1    You have 4+ years of experience as a Data Scie...
# 2    Job Brief\nThe ideal candidate will have previ...
# 3    Backed by $153MM in venture funding from top i...
# 4    PulsePoint™, a global programmatic advertising...
# ..                                                 ...
# 968  There is no shortage of computational and stat...
# 969  Good understanding of machine learning and dat...
# 970  You will collaborate with cross-functional tea...
# 971  The Business Planning and Analysis (BP&A) team...
# 972  The ideal candidate will have experience in Pr...
#
#                      Company Name  \
# 0                        [hopper]
# 1                  [noom, us, nu]
# 2            [ifg, companies, ic]
# 3           [quartet, health, qh]
# 4                    [pulsepoint]
# ..                            ...
# 968         [root, insurance, ri]
# 969             [tephra, inc, ti]
# 970        [tiger, analytics, ta]
# 971  [jpmorgan, chase, bank, jcb]
# 972         [root, insurance, ri]
#
#                               job_description_word_set  \
# 0    {research, startup, improv, hive, ambit, dynam...
# 1    {research, standard, analysi, team, superior, ...
# 2    {research, dataset, support, properti, detail,...
# 3    {research, password, corpor, tensorflow, scien...
# 4    {support, tree, improv, group, hive, variou, s...
# ..                                                 ...
# 968  {industri, research, group, spark, scientist, ...
# 969  {standard, industri, research, assign, improv,...
# 970  {standard, experienc, acumen, posit, scalabl, ...
# 971  {research, support, superior, leadership, infe...
# 972  {research, build, team, scale, leadership, dem...
#
#                                              tool_list  \
# 0      [sa, sql, r, panda, unix, hive, linux, tableau]
# 1                   [sql, numpi, panda, python, excel]
# 2                                 [sa, sql, python, r]
# 3    [sql, numpi, git, scikit, panda, jupyt, docker...
# 4    [numpi, hadoop, panda, unix, docker, python, h...
# ..                                                 ...
# 968                            [python, sql, r, spark]
# 969                 [sql, r, python, excel, cloud, aw]
# 970            [sql, r, shini, python, excel, tableau]
# 971  [sa, sql, qlik, hadoop, excel, hive, spark, ta...
# 972                                       [aw, r, sql]
#
#                                             skill_list  degree_list  \
# 0    [research, statist, data mining, dashboard, vi...          1.0
# 1    [research, logist, data, commun, regress, stat...        999.0
# 2    [research, statist, predict, data modeling, op...          1.0
# 3    [research, data mining, probabl, account, expl...        999.0
# 4    [svm, segment, predict, logist, decision tree,...          1.0
# ..                                                 ...          ...
# 968  [research, statist, forecast, pipelin, machine...          2.0
# 969  [research, statist, data mining, natural langu...        999.0
# 970  [statist, optim, visual, classif, machine lear...          1.0
# 971  [research, statist, recommend, econom, optim, ...          1.0
# 972  [research, predict, pipelin, machine learning,...        999.0
#
#                                                  clean
# 0    [sa, sql, r, panda, unix, hive, linux, tableau...
# 1    [sql, numpi, panda, python, excel, research, l...
# 2    [sa, sql, python, r, research, statist, predic...
# 3    [sql, numpi, git, scikit, panda, jupyt, docker...
# 4    [numpi, hadoop, panda, unix, docker, python, h...
# ..                                                 ...
# 968  [python, sql, r, spark, research, statist, for...
# 969  [sql, r, python, excel, cloud, aw, research, s...
# 970  [sql, r, shini, python, excel, tableau, statis...
# 971  [sa, sql, qlik, hadoop, excel, hive, spark, ta...
# 972  [aw, r, sql, research, predict, pipelin, machi...
#
# [973 rows x 10 columns]

# %%
df_DE=new_list(df_DE)
df_DE
# Out:
#       index  JT                       Salary  \
# 0         0  DE  $80K-$150K (Glassdoor est.)
# 1         1  DE  $80K-$150K (Glassdoor est.)
# 2         2  DE  $80K-$150K (Glassdoor est.)
# 3         4  DE  $80K-$150K (Glassdoor est.)
# 4         6  DE  $80K-$150K (Glassdoor est.)
# ...     ...  ..                          ...
# 1162   2500  DE   $56K-$89K (Glassdoor est.)
# 1163   2503  DE   $56K-$89K (Glassdoor est.)
# 1164   2504  DE   $56K-$89K (Glassdoor est.)
# 1165   2514  DE  $76K-$128K (Glassdoor est.)
# 1166   2525  DE  $76K-$128K (Glassdoor est.)
#
#                                                      JD  \
# 0     **\nJob Overview\nAlong with the requirements ...
# 1     Key Responsibilities\n- Architect, build, and ...
# 2     Overview\nPosition Overview:\nSeeking a highly...
# 3     Data Engineer\nJob Details\nLevel\nExperienced...
# 4     Senior Data Engineer\nMaster’s degree in Infor...
# ...                                                 ...
# 1162  Organization: Accenture Federal Services\nAcce...
# 1163  Job Responsibilities\nWrite well designed, tes...
# 1164  Your Opportunity\nThey help Marketing, Finance...
# 1165  Digital SW Eng Lead/Data Engineer\nIrving, TX\...
# 1166  Develop data collections, labeling pipelines, ...
#
#                                          Company Name  \
# 0                                           [sagence]
# 1                       [enterprise, integration, ei]
# 2                         [maestro, technologies, mt]
# 3                    [gny, insurance, companies, gic]
# 4                           [affinity, solutions, as]
# ...                                               ...
# 1162                    [solekai, systems, corp, ssc]
# 1163                                  [ntt, data, nd]
# 1164                                         [schwab]
# 1165                     [technocraft, solutions, ts]
# 1166  [cincinnati, bell, technology, solutions, cbts]
#
#                                job_description_word_set  \
# 0     {client, industri, datastax, variou, posit, mo...
# 1     {api, dataset, integr, capac, variou, spark, s...
# 2     {industri, fact, factori, glue, hive, spark, p...
# 3     {dataset, support, experienc, detail, semi, po...
# 4     {build, mapr, analysi, nosql, newsql, redshift...
# ...                                                 ...
# 1162  {client, strategi, depart, safeti, militari, p...
# 1163  {standard, research, support, dataset, protegr...
# 1164  {client, standard, industri, fact, support, le...
# 1165  {standard, eng, client, research, support, cov...
# 1166  {api, verif, tensorflow, dynam, more, elk, jav...
#
#                                               tool_list  \
# 0     [mongodb, sql, qlik, nosql, db, mysql, cloud, ...
# 1     [node, sql, hadoop, nosql, tableau, angular, j...
# 2     [hadoop, r, scala, java, python, lambda, azur,...
# 3                          [sql, r, python, excel, vba]
# 4     [sql, hadoop, nosql, redshift, python, spark, ...
# ...                                                 ...
# 1162                                             [None]
# 1163  [sql, hadoop, scala, unix, python, azur, spark...
# 1164  [mapreduc, git, hadoop, scala, db, unix, java,...
# 1165  [mapreduc, hadoop, nosql, c, java, pig, docker...
# 1166   [java, python, excel, tensorflow, elasticsearch]
#
#                                              skill_list  degree_list  \
# 0     [etl, data warehousing, commun, data modeling,...            2
# 1                 [etl, pipelin, busi, data, healthcar]          999
# 2     [statist, etl, econom, optim, data warehousing...            1
# 3     [information technology, etl, recommend, data ...            1
# 4      [information technology, data, machine learning]            2
# ...                                                 ...          ...
# 1162                                             [busi]          999
# 1163               [research, busi, segment, recommend]            1
# 1164  [etl, pipelin, commun, financ, risk, big data,...            1
# 1165  [research, etl, pipelin, commun, big data, bus...            1
# 1166  [recommend, dashboard, optim, pipelin, unsuper...            2
#
#                                                   clean
# 0     [mongodb, sql, qlik, nosql, db, cloud, postgre...
# 1     [node, sql, hadoop, nosql, tableau, angular, j...
# 2     [hadoop, r, scala, java, python, lambda, azur,...
# 3     [sql, r, python, excel, vba, information techn...
# 4     [sql, hadoop, nosql, redshift, python, spark, ...
# ...                                                 ...
# 1162                                             [busi]
# 1163  [sql, hadoop, scala, unix, python, azur, spark...
# 1164  [mapreduc, git, hadoop, scala, db, unix, java,...
# 1165  [mapreduc, hadoop, nosql, c, java, pig, docker...
# 1166  [java, python, excel, tensorflow, elasticsearc...
#
# [1167 rows x 10 columns]

# %% [markdown]
# # LDA List Implementation

# %%
import csv

with open('LDA_List', newline='') as f:
    reader = csv.reader(f)
    data = list(reader)

# %%
lda_list=[]
for lda in data:
    for item in lda:
        word=item.split("('")[1].split("'")[0]
        lda_list.append(word)

# %%
from nltk import pos_tag
from nltk.stem import PorterStemmer

ps = PorterStemmer()

# process the keywords
lda_list_set = set([ps.stem(tok) for tok in lda_list])

# %%
# process the job description.
def prepare_job_desc(desc):
    # tokenize description.
    desc=desc.replace("-"," ")
    desc=desc.replace("/"," ")
    tokens = [x for x in word_tokenize(desc) if x.isalnum()]
        
    # Parts of speech (POS) tag tokens.
    token_tag = pos_tag(tokens)
    
    # Only include some of the POS tags.
    include_tags = ['VBN', 'VBD', 'JJ', 'JJS', 'JJR', 'CD', 'NN', 'NNS', 'NNP', 'NNPS']
    filtered_tokens = [tok for tok, tag in token_tag if tag in include_tags]
    
    # stem words.
    stemmed_tokens = [ps.stem(tok).lower() for tok in filtered_tokens]
    return set(stemmed_tokens)

# %%
def mapping_list(df):
    name=get_df_name(df)
    df['JT']=name.split("_")[1]
    df['job_description_word_set'] =df['JD'].map(prepare_job_desc)
    
    lda_list = []
   

    num_postings = len(df.index)
    for i in range(num_postings):
        job_desc = df.iloc[i]['JD'].lower()
        job_desc_set = df.iloc[i]['job_description_word_set']

        # check if the keywords are in the job description. Look for exact match by token.
        lda_words = lda_list_set.intersection(job_desc_set)

        
        if len(lda_words) == 0:
            lda_words=[None]
    
                
        lda_list.append(list(lda_words))
    
    return lda_list

# %%
def get_df_name(df):
    name =[x for x in globals() if globals()[x] is df][0]
    return name

# %%
def df_with_feature(df):
    df["lda_list"]= mapping_list(df)
    return df

# %%
def combine1(clean,lda):
    res=[]

    new=clean+lda
    for word in new:
        if word!=None:
            res.append(word)
    return res

# %%
def new_list(df):
    df=df_with_feature(df)

    df["newlist"] =df.apply(lambda x: x['clean']+x['lda_list'],axis=1)


    return df

# %%
df_BA=new_list(df_BA)
df_DA=new_list(df_DA)
df_DS=new_list(df_DS)
df_DE=new_list(df_DE)

# %%
df_BA['JT']="BA"
df_DS['JT']="DS"
df_DE['JT']="DE"

# %% [markdown]
# # Export the Dataset

# %%
def final_clean(df):
    return df[['JT','JD','tool_list','skill_list','degree_list','clean','lda_list','newlist']]

# %%
final_clean(df_BA).to_csv('BA',index=False)
final_clean(df_DS).to_csv('DS',index=False)
final_clean(df_DA).to_csv('DA',index=False)
final_clean(df_DE).to_csv('DE',index=False)
